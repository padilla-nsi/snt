# %% [markdown]
# # Le routage sur Internet

# %% [markdown]
# Comment un e-mail ne comportant que l'adresse de l'**expéditeur** et du **destinataire** fait-il pour circuler sur Internet.... et arriver à destination ?
#
# Nous allons essayer de comprendre cela !

# %% [markdown]
# ## 1. Étapes du protocole

# %% [markdown]
# **Étape 1.**
# Chaque élève choisit un *identifiant* à 3 chiffres. Cet identifiant est **secret** et doit être différent pour chaque élève.

# %% [markdown]
# **Étape 2.**
# Chaque élève crée sa **table de routage** personnelle en indiquant sur la feuille son *prénom* en première ligne suivie de `(par -)`

# %% [markdown]
# **Étape 3.**
# Chaque élève :
#
# 1. *fait une copie* de sa table de routage (sur une autre feuille),
# 2. ajoute son numéro secret d'expéditeur dans l'en-tête,
# 3. transmet *la copie* à l'élève à qui il est *connecté*.

# %% [markdown]
# **Étape 4.**
# Lorsqu'un élève reçoit la table de routage d'un de ses nœuds, il effectue le traitement suivant :
#
# * Comparer la table reçue avec sa table personnelle.
# * Si un *nouveau prénom* apparaît, ajouter une ligne dans la table personnelle en indiquant : `<nouveau prénom> (par <identifiant secret de expéditeur>)`.
# * Supprimer la table reçue (pour la poubelle de recyclage SVP).

# %% [markdown]
# **Étape 5.**
# Si la table de routage a été modifiée, l'élève :
#
# * fait la liste des expéditeurs avec qui il est connecté,
# * fait autant de copie de sa table de routage qu'il y a d'expéditeur,
# * envoie une copie de sa table à chaque expéditeur.
#
# Ensuite, l'élève reprend en boucle son attente à l'**étape 4**.

# %% [markdown]
# ## 2. Exemples et activités

# %% [markdown]
# Imaginons un réseau de 3 élèves connectés ainsi :
#
# * Djamel ~(456)~ -> Ada ~(789)~
# * Frédérique ~(123)~ -> Djamel ~(456)~
#
# Alors après l'**étape 2** Djamel écrira sur sa table de routage :
#
#     Table de routage de <identifiant secret>
#     DJAMEL (par -)

# %% [markdown]
# Quelles informations nouvelles possède chaque correspondant ? Quel est maintenant le nombre de correspondant de chaque élève ?

# %% [markdown]
# Quelle sera la table de routage de Frédérique ?

# %% [markdown]
# Indiquer les tables de Djamel et Ada après l'étape 4.
#
# La table de Frédérique a-t-elle été modifiée ?

# %% [markdown]
# Écrire les tables finales obtenues par Djamel, Ada et Frédérique lorsqu'il n'y a plus de messages échangés.
